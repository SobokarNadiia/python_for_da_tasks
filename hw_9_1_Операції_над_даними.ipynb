# %% [markdown]
# <a href="https://colab.research.google.com/github/SobokarNadiia/python_for_da_tasks/blob/main/hw_9_1_%D0%9E%D0%BF%D0%B5%D1%80%D0%B0%D1%86%D1%96%D1%97_%D0%BD%D0%B0%D0%B4_%D0%B4%D0%B0%D0%BD%D0%B8%D0%BC%D0%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Домашнє завдання до теми "Основи роботи з рядками та математичні операції"

# %% [markdown]
# 1. Створіть змінні `a`, `b`, `c` та `d`, задайте їм значення відповідно 101, 210, 111, 402, та обчисліть з допомогою Python наступний вираз:  $$ \frac{(a+b) * c}{d} $$
#
# **Важливо**: тут ми маємо обчислити значення саме з використанням змінних, а не просто чисел, як би ми робили у калькуряторі. Змінні потрібні аби за бажання ми могли змінити їх значення та не переписувати код обчислення виразу, бо він буде працювати для різних значень змінних.

# %%
a = 101
b = 210
c = 111
d = 402

(a + b) * c / d
# Out:
# 85.8731343283582

# %% [markdown]
# Очікувана відповідь: 85.8731343283582

# %% [markdown]
# 2. Якою буде остача від ділення числа 11283 на 89? Обчисліть з допомогою Python.

# %%
11283 % 89
# Out:
# 69

# %% [markdown]
# 3. Скільки цілих разів поміститься число 89 в 11283? (Або що те саме: який буде результат цілочисельного ділення 11283 на 89?)

# %%
11283 // 89
# Out:
# 126

# %% [markdown]
# 4. Запишіть у змінну `name` ваше імʼя.

# %%
name = 'Nadiia'

# %% [markdown]
# 5. Запишіть у змінну `surname` ваше прізвище.

# %%
surname = 'Sobokar'

# %% [markdown]
# 6. Сконкатенуйте імʼя та прізвище в одну фразу через пробіл. Запишіть результат у нову змінну `name_surname` та виведіть результат на екран.

# %%
name_surname = name + ' ' + surname
name_surname
# Out:
# 'Nadiia Sobokar'

# %% [markdown]
# Очікувана відповідь (тільки з вашими даними): 'Hanna Pylieva'

# %% [markdown]
# 7. Зробіть усі літери змінної `name_surname` заглавними використовуючи метод рядків в Python:

# %%
name_surname.upper()
# Out:
# 'NADIIA SOBOKAR'

# %% [markdown]
# Очікувана відповідь (тільки з вашими даними): 'HANNA PYLIEVA'

# %% [markdown]
# 8. Виведіть третю літеру вашого `name_surname`. Тут уважно, треба саме третя літера. Згадайте, з якого значення починається індексування значень в Python.

# %%
name_surname[2]
# Out:
# 'd'

# %% [markdown]
# Очікувана відповідь (тільки з вашими даними): 'n'

# %% [markdown]
# 9. Виведіть першу та останню літеру вашого прізвища.

# %%
print(surname[0], surname[-1])
# Out:
# S r

# %% [markdown]
# Очікувана відповідь (тільки з вашими даними): ('P', 'a')

# %% [markdown]
# 10. Виведіть довжину вашого прізвища.

# %%
len(surname)
# Out:
# 7

# %% [markdown]
# Очікувана відповідь (тільки з вашими даними): 7

# %% [markdown]
# 11. Виведіть кількість літер `a` у столиці Мадагаскару `Antananarivo`. Важливо врахувати всі літери, як великі, так і маленькі.

# %%
capital = 'Antananarivo'
capital = capital.lower()
print(len(capital))
count = 0
count = capital[0] == 'a'
count += capital[2] == 'a'
count += capital[3] == 'a'
count += capital[4] == 'a'
count += capital[5] == 'a'
count += capital[6] == 'a'
count += capital[7] == 'a'
count += capital[8] == 'a'
count += capital[9] == 'a'
count += capital[10] == 'a'
count += capital[11] == 'a'
count
# Out:
# 12
# 4

# %% [markdown]
# Очікувана відповідь: 4

# %% [markdown]
# Наступні вправи можуть здатись дещо складніше - вони для найуважніших!
# Якщо не виходить - не страшно. Пишіть нам в чат, ми підкажемо!

# %% [markdown]
# 12. Створіть рядок `my_string` зі значенням: "The quick brown fox jumps over the lazy dog!!!".
# Перевірте, чи починається рядок `my_string` з "The" і чи закінчується він "dog!". Виведіть результати на екран.

# %%
my_string =  "The quick brown fox jumps over the lazy dog!!!"
print(my_string.startswith('The'))
print(my_string.endswith('dog!'))
# Out:
# True
# False

# %% [markdown]
# 13. Розділіть рядок `my_string` на список окремих слів, а потім з'єднайте всі слова через нижнє підкреслювання. Виведіть результат на екран.

# %%
my_string.replace(' ', '_')   # я розумію, що потрібно було спочатку split зробити, а потім їх сконкатувати якось, але я тількт так здогадалась(
# Out:
# 'The_quick_brown_fox_jumps_over_the_lazy_dog!!!'

# %%
new = my_string.split(' ')
new[0] + '_' + new[1] + '_' + new[2] + '_' + new[3] + '_' + new[4] + '_' + new[5] + '_' + new[6] + '_' + new[7] + '_' + new[8]    #я тільки до такого додумалась
# Out:
# 'The_quick_brown_fox_jumps_over_the_lazy_dog!!!'

# %% [markdown]
# Очікуваний результат: `The_quick_brown_fox_jumps_over_the_lazy_dog!!!`
